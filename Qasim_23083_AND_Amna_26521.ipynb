# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head(15)
# Out:
#                  Employee ID Date of Joining  Gender Company Type  \
# 0   fffe32003000360033003200       9/30/2008  Female      Service
# 1       fffe3700360033003500      11/30/2008    Male      Service
# 2   fffe31003300320037003900       3/10/2008  Female      Product
# 3   fffe32003400380032003900       11/3/2008    Male      Service
# 4   fffe31003900340031003600       7/24/2008  Female      Service
# 5       fffe3300350037003500      11/26/2008    Male      Product
# 6   fffe33003300340039003100        1/2/2008  Female      Service
# 7   fffe32003600320037003400      10/31/2008  Female      Service
# 8   fffe32003200300034003700      12/27/2008  Female      Service
# 9   fffe31003600320030003200        3/9/2008  Female      Product
# 10  fffe33003100330032003700       3/16/2008    Male      Product
# 11      fffe3400310035003800       5/12/2008    Male      Service
# 12  fffe32003100300030003700       1/20/2008    Male      Service
# 13  fffe31003800330032003500       2/23/2008  Female      Product
# 14  fffe33003100330036003300       5/14/2008    Male      Product
#
#    WFH Setup Available  Designation  Resource Allocation  \
# 0                   No            2                  3.0
# 1                  Yes            1                  2.0
# 2                  Yes            2                  NaN
# 3                  Yes            1                  1.0
# 4                   No            3                  7.0
# 5                  Yes            2                  4.0
# 6                   No            3                  6.0
# 7                  Yes            2                  4.0
# 8                   No            3                  6.0
# 9                   No            3                  6.0
# 10                 Yes            2                  3.0
# 11                 Yes            0                  1.0
# 12                 Yes            2                  5.0
# 13                  No            1                  3.0
# 14                 Yes            1                  3.0
#
#     Mental Fatigue Score  Burn Rate
# 0                    3.8       0.16
# 1                    5.0       0.36
# 2                    5.8       0.49
# 3                    2.6       0.20
# 4                    6.9       0.52
# 5                    3.6       0.29
# 6                    7.9       0.62
# 7                    4.4       0.33
# 8                    NaN       0.56
# 9                    NaN       0.67
# 10                   5.3       0.50
# 11                   1.8       0.12
# 12                   NaN       0.40
# 13                   NaN       0.33
# 14                   5.8       0.51

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  object
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.6+ MB

# %%
train.describe()
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score     Burn Rate
# count  22750.000000         21369.000000          20633.000000  21626.000000
# mean       2.178725             4.481398              5.728188      0.452005
# std        1.135145             2.047211              1.920839      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.600000      0.310000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %%
plt.figure(figsize = (10,6))
sns.boxplot(train['Burn Rate'])
plt.title('Burn Rate')
plt.show()

# %%
import datetime as dt

# %%
train['Date of Joining'] = pd.to_datetime(train['Date of Joining'])

# %%
train.head(15)
# Out:
#                  Employee ID Date of Joining  Gender Company Type  \
# 0   fffe32003000360033003200      2008-09-30  Female      Service
# 1       fffe3700360033003500      2008-11-30    Male      Service
# 2   fffe31003300320037003900      2008-03-10  Female      Product
# 3   fffe32003400380032003900      2008-11-03    Male      Service
# 4   fffe31003900340031003600      2008-07-24  Female      Service
# 5       fffe3300350037003500      2008-11-26    Male      Product
# 6   fffe33003300340039003100      2008-01-02  Female      Service
# 7   fffe32003600320037003400      2008-10-31  Female      Service
# 8   fffe32003200300034003700      2008-12-27  Female      Service
# 9   fffe31003600320030003200      2008-03-09  Female      Product
# 10  fffe33003100330032003700      2008-03-16    Male      Product
# 11      fffe3400310035003800      2008-05-12    Male      Service
# 12  fffe32003100300030003700      2008-01-20    Male      Service
# 13  fffe31003800330032003500      2008-02-23  Female      Product
# 14  fffe33003100330036003300      2008-05-14    Male      Product
#
#    WFH Setup Available  Designation  Resource Allocation  \
# 0                   No            2                  3.0
# 1                  Yes            1                  2.0
# 2                  Yes            2                  NaN
# 3                  Yes            1                  1.0
# 4                   No            3                  7.0
# 5                  Yes            2                  4.0
# 6                   No            3                  6.0
# 7                  Yes            2                  4.0
# 8                   No            3                  6.0
# 9                   No            3                  6.0
# 10                 Yes            2                  3.0
# 11                 Yes            0                  1.0
# 12                 Yes            2                  5.0
# 13                  No            1                  3.0
# 14                 Yes            1                  3.0
#
#     Mental Fatigue Score  Burn Rate
# 0                    3.8       0.16
# 1                    5.0       0.36
# 2                    5.8       0.49
# 3                    2.6       0.20
# 4                    6.9       0.52
# 5                    3.6       0.29
# 6                    7.9       0.62
# 7                    4.4       0.33
# 8                    NaN       0.56
# 9                    NaN       0.67
# 10                   5.3       0.50
# 11                   1.8       0.12
# 12                   NaN       0.40
# 13                   NaN       0.33
# 14                   5.8       0.51

# %%
def get_y_m_d(train):
    train['Years'] = train['Date of Joining'].dt.year
    train['Months'] = train['Date of Joining'].dt.month
    train['Date'] = train['Date of Joining'].dt.day
    return train

# %%
train = get_y_m_d(train)

# %%
train.drop(columns =['Date of Joining'],inplace = True)

# %%
train.head(15)
# Out:
#                  Employee ID  Gender Company Type WFH Setup Available  \
# 0   fffe32003000360033003200  Female      Service                  No
# 1       fffe3700360033003500    Male      Service                 Yes
# 2   fffe31003300320037003900  Female      Product                 Yes
# 3   fffe32003400380032003900    Male      Service                 Yes
# 4   fffe31003900340031003600  Female      Service                  No
# 5       fffe3300350037003500    Male      Product                 Yes
# 6   fffe33003300340039003100  Female      Service                  No
# 7   fffe32003600320037003400  Female      Service                 Yes
# 8   fffe32003200300034003700  Female      Service                  No
# 9   fffe31003600320030003200  Female      Product                  No
# 10  fffe33003100330032003700    Male      Product                 Yes
# 11      fffe3400310035003800    Male      Service                 Yes
# 12  fffe32003100300030003700    Male      Service                 Yes
# 13  fffe31003800330032003500  Female      Product                  No
# 14  fffe33003100330036003300    Male      Product                 Yes
#
#     Designation  Resource Allocation  Mental Fatigue Score  Burn Rate  Years  \
# 0             2                  3.0                   3.8       0.16   2008
# 1             1                  2.0                   5.0       0.36   2008
# 2             2                  NaN                   5.8       0.49   2008
# 3             1                  1.0                   2.6       0.20   2008
# 4             3                  7.0                   6.9       0.52   2008
# 5             2                  4.0                   3.6       0.29   2008
# 6             3                  6.0                   7.9       0.62   2008
# 7             2                  4.0                   4.4       0.33   2008
# 8             3                  6.0                   NaN       0.56   2008
# 9             3                  6.0                   NaN       0.67   2008
# 10            2                  3.0                   5.3       0.50   2008
# 11            0                  1.0                   1.8       0.12   2008
# 12            2                  5.0                   NaN       0.40   2008
# 13            1                  3.0                   NaN       0.33   2008
# 14            1                  3.0                   5.8       0.51   2008
#
#     Months  Date
# 0        9    30
# 1       11    30
# 2        3    10
# 3       11     3
# 4        7    24
# 5       11    26
# 6        1     2
# 7       10    31
# 8       12    27
# 9        3     9
# 10       3    16
# 11       5    12
# 12       1    20
# 13       2    23
# 14       5    14

# %%
train['Company Type'].value_counts()
# Out:
# Service    14833
# Product     7917
# Name: Company Type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()

# %%
train['Gender']=lab_enc.fit_transform(train['Gender'])

# %%
train['Company Type']=lab_enc.fit_transform(train['Company Type'])
train['WFH Setup Available']=lab_enc.fit_transform(train['WFH Setup Available'])

# %%
train.head(15)
# Out:
#                  Employee ID  Gender  Company Type  WFH Setup Available  \
# 0   fffe32003000360033003200       0             1                    0
# 1       fffe3700360033003500       1             1                    1
# 2   fffe31003300320037003900       0             0                    1
# 3   fffe32003400380032003900       1             1                    1
# 4   fffe31003900340031003600       0             1                    0
# 5       fffe3300350037003500       1             0                    1
# 6   fffe33003300340039003100       0             1                    0
# 7   fffe32003600320037003400       0             1                    1
# 8   fffe32003200300034003700       0             1                    0
# 9   fffe31003600320030003200       0             0                    0
# 10  fffe33003100330032003700       1             0                    1
# 11      fffe3400310035003800       1             1                    1
# 12  fffe32003100300030003700       1             1                    1
# 13  fffe31003800330032003500       0             0                    0
# 14  fffe33003100330036003300       1             0                    1
#
#     Designation  Resource Allocation  Mental Fatigue Score  Burn Rate  Years  \
# 0             2                  3.0                   3.8       0.16   2008
# 1             1                  2.0                   5.0       0.36   2008
# 2             2                  NaN                   5.8       0.49   2008
# 3             1                  1.0                   2.6       0.20   2008
# 4             3                  7.0                   6.9       0.52   2008
# 5             2                  4.0                   3.6       0.29   2008
# 6             3                  6.0                   7.9       0.62   2008
# 7             2                  4.0                   4.4       0.33   2008
# 8             3                  6.0                   NaN       0.56   2008
# 9             3                  6.0                   NaN       0.67   2008
# 10            2                  3.0                   5.3       0.50   2008
# 11            0                  1.0                   1.8       0.12   2008
# 12            2                  5.0                   NaN       0.40   2008
# 13            1                  3.0                   NaN       0.33   2008
# 14            1                  3.0                   5.8       0.51   2008
#
#     Months  Date
# 0        9    30
# 1       11    30
# 2        3    10
# 3       11     3
# 4        7    24
# 5       11    26
# 6        1     2
# 7       10    31
# 8       12    27
# 9        3     9
# 10       3    16
# 11       5    12
# 12       1    20
# 13       2    23
# 14       5    14

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Gender                22750 non-null  int32
#  2   Company Type          22750 non-null  int32
#  3   WFH Setup Available   22750 non-null  int32
#  4   Designation           22750 non-null  int64
#  5   Resource Allocation   21369 non-null  float64
#  6   Mental Fatigue Score  20633 non-null  float64
#  7   Burn Rate             21626 non-null  float64
#  8   Years                 22750 non-null  int64
#  9   Months                22750 non-null  int64
#  10  Date                  22750 non-null  int64
# dtypes: float64(3), int32(3), int64(4), object(1)
# memory usage: 1.6+ MB

# %%
train.describe()
# Out:
#              Gender  Company Type  WFH Setup Available   Designation  \
# count  22750.000000  22750.000000         22750.000000  22750.000000
# mean       0.476571      0.652000             0.540220      2.178725
# std        0.499462      0.476346             0.498391      1.135145
# min        0.000000      0.000000             0.000000      0.000000
# 25%        0.000000      0.000000             0.000000      1.000000
# 50%        0.000000      1.000000             1.000000      2.000000
# 75%        1.000000      1.000000             1.000000      3.000000
# max        1.000000      1.000000             1.000000      5.000000
#
#        Resource Allocation  Mental Fatigue Score     Burn Rate    Years  \
# count         21369.000000          20633.000000  21626.000000  22750.0
# mean              4.481398              5.728188      0.452005   2008.0
# std               2.047211              1.920839      0.198226      0.0
# min               1.000000              0.000000      0.000000   2008.0
# 25%               3.000000              4.600000      0.310000   2008.0
# 50%               4.000000              5.900000      0.450000   2008.0
# 75%               6.000000              7.100000      0.590000   2008.0
# max              10.000000             10.000000      1.000000   2008.0
#
#              Months          Date
# count  22750.000000  22750.000000
# mean       6.509978     15.760659
# std        3.440477      8.769239
# min        1.000000      1.000000
# 25%        4.000000      8.000000
# 50%        7.000000     16.000000
# 75%        9.000000     23.000000
# max       12.000000     31.000000

# %%
mean1 = train.groupby('Company Type').mean()['Resource Allocation'].round().loc[0]
mean2 = train.groupby('Company Type').mean()['Resource Allocation'].round().loc[1]
train.loc[train['Company Type']==0,'Resource Allocation'] = train.loc[train['Company Type']==0,'Resource Allocation'].fillna(value=mean1)
train.loc[train['Company Type']==1,'Resource Allocation'] = train.loc[train['Company Type']==1,'Resource Allocation'].fillna(value=mean1)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5080\447100114.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean1 = train.groupby('Company Type').mean()['Resource Allocation'].round().loc[0]
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5080\447100114.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean2 = train.groupby('Company Type').mean()['Resource Allocation'].round().loc[1]

# %%
mean1 = round((train.groupby('Company Type').mean()['Mental Fatigue Score'].loc[0]),1)
mean2 = round((train.groupby('Company Type').mean()['Mental Fatigue Score'].loc[1]),1)
train.loc[train['Company Type']==0,'Mental Fatigue Score'] = train.loc[train['Company Type']==0,'Mental Fatigue Score'].fillna(value=mean1)
train.loc[train['Company Type']==1,'Mental Fatigue Score'] = train.loc[train['Company Type']==1,'Mental Fatigue Score'].fillna(value=mean1)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5080\3634566504.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean1 = round((train.groupby('Company Type').mean()['Mental Fatigue Score'].loc[0]),1)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5080\3634566504.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean2 = round((train.groupby('Company Type').mean()['Mental Fatigue Score'].loc[1]),1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Gender                22750 non-null  int32
#  2   Company Type          22750 non-null  int32
#  3   WFH Setup Available   22750 non-null  int32
#  4   Designation           22750 non-null  int64
#  5   Resource Allocation   22750 non-null  float64
#  6   Mental Fatigue Score  22750 non-null  float64
#  7   Burn Rate             21626 non-null  float64
#  8   Years                 22750 non-null  int64
#  9   Months                22750 non-null  int64
#  10  Date                  22750 non-null  int64
# dtypes: float64(3), int32(3), int64(4), object(1)
# memory usage: 1.6+ MB

# %%
s=0
for i in range(len(train['Burn Rate'])):
    if train['Burn Rate'][i]<0:
        print(train['Burn Rate'][i])
        s+=1
print(s)
# Out:
# 0

# %%
train = train[train['Burn Rate']>=0]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21626 entries, 0 to 22749
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           21626 non-null  object
#  1   Gender                21626 non-null  int32
#  2   Company Type          21626 non-null  int32
#  3   WFH Setup Available   21626 non-null  int32
#  4   Designation           21626 non-null  int64
#  5   Resource Allocation   21626 non-null  float64
#  6   Mental Fatigue Score  21626 non-null  float64
#  7   Burn Rate             21626 non-null  float64
#  8   Years                 21626 non-null  int64
#  9   Months                21626 non-null  int64
#  10  Date                  21626 non-null  int64
# dtypes: float64(3), int32(3), int64(4), object(1)
# memory usage: 1.7+ MB

# %%
tarin = train.drop(columns = 'Employee ID',inplace =True)

# %%
train.head(15)
# Out:
#     Gender  Company Type  WFH Setup Available  Designation  \
# 0        0             1                    0            2
# 1        1             1                    1            1
# 2        0             0                    1            2
# 3        1             1                    1            1
# 4        0             1                    0            3
# 5        1             0                    1            2
# 6        0             1                    0            3
# 7        0             1                    1            2
# 8        0             1                    0            3
# 9        0             0                    0            3
# 10       1             0                    1            2
# 11       1             1                    1            0
# 12       1             1                    1            2
# 13       0             0                    0            1
# 14       1             0                    1            1
#
#     Resource Allocation  Mental Fatigue Score  Burn Rate  Years  Months  Date
# 0                   3.0                   3.8       0.16   2008       9    30
# 1                   2.0                   5.0       0.36   2008      11    30
# 2                   4.0                   5.8       0.49   2008       3    10
# 3                   1.0                   2.6       0.20   2008      11     3
# 4                   7.0                   6.9       0.52   2008       7    24
# 5                   4.0                   3.6       0.29   2008      11    26
# 6                   6.0                   7.9       0.62   2008       1     2
# 7                   4.0                   4.4       0.33   2008      10    31
# 8                   6.0                   5.7       0.56   2008      12    27
# 9                   6.0                   5.7       0.67   2008       3     9
# 10                  3.0                   5.3       0.50   2008       3    16
# 11                  1.0                   1.8       0.12   2008       5    12
# 12                  5.0                   5.7       0.40   2008       1    20
# 13                  3.0                   5.7       0.33   2008       2    23
# 14                  3.0                   5.8       0.51   2008       5    14

# %%
sns.pairplot(train,hue = 'Burn Rate',palette='hls')
plt.title('Distribusion of data points')
plt.show()

# %%
plt.figure(figsize= (15,15))
sns.heatmap(train.corr(),annot =True,fmt = '.2%')
plt.show()

# %%
y = train.iloc[:,6].values
x = train.drop(['Burn Rate'],axis = 1).values

# %%
print(x.shape)
print(y.shape)
# Out:
# (21626, 9)
# (21626,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit_transform(x)
# Out:
# array([[-0.95159988,  0.7288022 , -1.08417483, ...,  0.        ,
#          0.7238327 ,  1.62233089],
#        [ 1.05086184,  0.7288022 ,  0.92236046, ...,  0.        ,
#          1.30499497,  1.62233089],
#        [-0.95159988, -1.37211441,  0.92236046, ...,  0.        ,
#         -1.01965413, -0.65572248],
#        ...,
#        [ 1.05086184,  0.7288022 ,  0.92236046, ...,  0.        ,
#          1.30499497, -1.22523582],
#        [-0.95159988,  0.7288022 , -1.08417483, ...,  0.        ,
#         -1.6008164 , -0.65572248],
#        [ 1.05086184, -1.37211441, -1.08417483, ...,  0.        ,
#         -1.6008164 , -1.11133316]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr_score = lr.score(x,y)

# %%
test['Date of Joining'] = pd.to_datetime(test['Date of Joining'])

# %%
def get_y_m_d(test):
    test['Year'] = test['Date of Joining'].dt.year
    test['Month'] = test['Date of Joining'].dt.month
    test['Date'] = test['Date of Joining'].dt.day
    test.drop(columns = ['Date of Joining'],inplace =True)
    return test

# %%
test = get_y_m_d(test)

# %%
test
# Out:
#                     Employee ID  Gender Company Type WFH Setup Available  \
# 0      fffe31003300390039003000  Female      Service                  No
# 1      fffe31003300310037003800  Female      Product                 Yes
# 2      fffe33003400380035003900    Male      Product                 Yes
# 3          fffe3100370039003200  Female      Service                  No
# 4      fffe32003600390036003700  Female      Product                  No
# ...                         ...     ...          ...                 ...
# 12245      fffe3900310034003700  Female      Service                 Yes
# 12246  fffe32003600330034003000  Female      Product                 Yes
# 12247  fffe31003800340039003000    Male      Service                  No
# 12248  fffe32003600380031003800    Male      Service                  No
# 12249  fffe32003100390037003800  Female      Product                  No
#
#        Designation  Resource Allocation  Mental Fatigue Score  Year  Month  \
# 0              2.0                  5.0                   7.7  2008     12
# 1              1.0                  2.0                   5.2  2008      8
# 2              1.0                  3.0                   5.9  2008     11
# 3              3.0                  6.0                   4.6  2008      2
# 4              2.0                  5.0                   6.4  2008      7
# ...            ...                  ...                   ...   ...    ...
# 12245          1.0                  2.0                   6.1  2008     10
# 12246          2.0                  4.0                   5.9  2008      3
# 12247          4.0                  7.0                   9.6  2008      2
# 12248          3.0                  6.0                   6.7  2008      2
# 12249          2.0                  2.0                   2.0  2008      8
#
#        Date
# 0        10
# 1        14
# 2        13
# 3         7
# 4        17
# ...     ...
# 12245     2
# 12246    31
# 12247    12
# 12248     6
# 12249     5
#
# [12250 rows x 10 columns]

# %%
test['Gender']=lab_enc.fit_transform(test['Gender'])
test['Company Type']=lab_enc.fit_transform(test['Company Type'])
test['WFH Setup Available']=lab_enc.fit_transform(test['WFH Setup Available'])

# %%
test
# Out:
#                     Employee ID  Gender  Company Type  WFH Setup Available  \
# 0      fffe31003300390039003000       0             1                    0
# 1      fffe31003300310037003800       0             0                    1
# 2      fffe33003400380035003900       1             0                    1
# 3          fffe3100370039003200       0             1                    0
# 4      fffe32003600390036003700       0             0                    0
# ...                         ...     ...           ...                  ...
# 12245      fffe3900310034003700       0             1                    1
# 12246  fffe32003600330034003000       0             0                    1
# 12247  fffe31003800340039003000       1             1                    0
# 12248  fffe32003600380031003800       1             1                    0
# 12249  fffe32003100390037003800       0             0                    0
#
#        Designation  Resource Allocation  Mental Fatigue Score  Year  Month  \
# 0              2.0                  5.0                   7.7  2008     12
# 1              1.0                  2.0                   5.2  2008      8
# 2              1.0                  3.0                   5.9  2008     11
# 3              3.0                  6.0                   4.6  2008      2
# 4              2.0                  5.0                   6.4  2008      7
# ...            ...                  ...                   ...   ...    ...
# 12245          1.0                  2.0                   6.1  2008     10
# 12246          2.0                  4.0                   5.9  2008      3
# 12247          4.0                  7.0                   9.6  2008      2
# 12248          3.0                  6.0                   6.7  2008      2
# 12249          2.0                  2.0                   2.0  2008      8
#
#        Date
# 0        10
# 1        14
# 2        13
# 3         7
# 4        17
# ...     ...
# 12245     2
# 12246    31
# 12247    12
# 12248     6
# 12249     5
#
# [12250 rows x 10 columns]

# %%
x_test = test.drop(columns = ['Employee ID'],axis=1).values

# %%
sc.fit_transform(x_test)
# Out:
# array([[-0.94905122,  0.72834385, -1.08757644, ...,  0.        ,
#          1.58312674, -0.64685327],
#        [-0.94905122, -1.37297789,  0.9194756 , ...,  0.        ,
#          0.43001613, -0.19361569],
#        [ 1.05368391, -1.37297789,  0.9194756 , ...,  0.        ,
#          1.29484909, -0.30692509],
#        ...,
#        [ 1.05368391,  0.72834385, -1.08757644, ...,  0.        ,
#         -1.29964979, -0.42023448],
#        [ 1.05368391,  0.72834385, -1.08757644, ...,  0.        ,
#         -1.29964979, -1.10009084],
#        [-0.94905122, -1.37297789, -1.08757644, ...,  0.        ,
#          0.43001613, -1.21340023]])

# %%
from sklearn.tree import DecisionTreeRegressor
ds = DecisionTreeRegressor()

# %%
ds.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
ds_score =ds.score(x,y)

# %%
from sklearn.ensemble import RandomForestRegressor
lf=RandomForestRegressor(max_depth=19)

# %%
lf.fit(x,y)
# Out:
# RandomForestRegressor(max_depth=19)

# %%
lf_score = lf.score(x,y)

# %%
from tabulate import tabulate

# %%
table = []
table.append(['Sr.No.', 'Regression Model', 'Score'])
table.append(['1','Linear Regression',lr_score])
table.append(['2','Random Forest Regressor',ds_score])
table.append(['3','Decision Tree Regressor',lf_score])

print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤═════════════════════════╤══════════╕
# │   Sr.No. │ Regression Model        │    Score │
# ╞══════════╪═════════════════════════╪══════════╡
# │        1 │ Linear Regression       │ 0.870693 │
# ├──────────┼─────────────────────────┼──────────┤
# │        2 │ Random Forest Regressor │ 0.998862 │
# ├──────────┼─────────────────────────┼──────────┤
# │        3 │ Decision Tree Regressor │ 0.979997 │
# ╘══════════╧═════════════════════════╧══════════╛

# %%
#take prediction value with best score model

# %%
y_pred = lf.predict(x_test)
y_pred1 = np.around(y_pred,2)
y_pred1
# Out:
# array([0.62, 0.37, 0.45, ..., 0.83, 0.59, 0.14])

# %%
s = 0
for i in range(len(y_pred1)):
    if y_pred1[i]<0:
        print(y_pred1[i]<0)
        s +=1
print(s)
# Out:
# 0

# %%
test.head(15)

# %%
Emp_ID = test['Employee ID'].values

# %%
print(y_pred1.shape)
print(Emp_ID.shape)
# Out:
# (12250,)
# (12250,)

# %%
out = pd.DataFrame(list(zip(Emp_ID,y_pred1)),columns = ['Employee ID','Burn Rate'])

# %%
out
# Out:
#                     Employee ID  Burn Rate
# 0      fffe31003300390039003000       0.62
# 1      fffe31003300310037003800       0.37
# 2      fffe33003400380035003900       0.45
# 3          fffe3100370039003200       0.37
# 4      fffe32003600390036003700       0.54
# ...                         ...        ...
# 12245      fffe3900310034003700       0.40
# 12246  fffe32003600330034003000       0.44
# 12247  fffe31003800340039003000       0.83
# 12248  fffe32003600380031003800       0.59
# 12249  fffe32003100390037003800       0.14
#
# [12250 rows x 2 columns]
